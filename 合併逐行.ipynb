# %%
import matplotlib.pyplot as plt #plt 用于显示图片
import matplotlib.image as mpimg #mpimg 用于读取图片
import numpy as np
import pandas as pd

# %%
file = './replay.csv'
df = pd.read_csv(file,encoding='utf-8',keep_default_na=False,error_bad_lines=False)
# Out:
# b'Skipping line 7: expected 12 fields, saw 24\nSkipping line 8: expected 12 fields, saw 24\nSkipping line 28: expected 12 fields, saw 1317\nSkipping line 29: expected 12 fields, saw 1317\nSkipping line 30: expected 12 fields, saw 1317\nSkipping line 31: expected 12 fields, saw 1317\nSkipping line 32: expected 12 fields, saw 1317\nSkipping line 33: expected 12 fields, saw 1317\nSkipping line 34: expected 12 fields, saw 1317\nSkipping line 35: expected 12 fields, saw 1317\nSkipping line 36: expected 12 fields, saw 1317\nSkipping line 37: expected 12 fields, saw 1317\nSkipping line 38: expected 12 fields, saw 1317\nSkipping line 39: expected 12 fields, saw 1317\nSkipping line 40: expected 12 fields, saw 1317\nSkipping line 41: expected 12 fields, saw 1317\nSkipping line 42: expected 12 fields, saw 1317\nSkipping line 43: expected 12 fields, saw 1317\nSkipping line 44: expected 12 fields, saw 1317\nSkipping line 45: expected 12 fields, saw 1317\nSkipping line 46: expected 12 fields, saw 
# ...

# %%
df.shape
# Out:
# (51, 1)
